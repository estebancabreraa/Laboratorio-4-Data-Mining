# %%
from copy import deepcopy
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sb
from google.colab import files
# %matplotlib inline

# %%
upload = files.upload()
dt = pd.read_csv("insurance.csv") 
#df.drop('',axis=1,inplace=True)
dt.head()
# Out:
#      <input type="file" id="files-7c8fec6a-5e2d-4c2a-9a43-7a16a22a2bca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c8fec6a-5e2d-4c2a-9a43-7a16a22a2bca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving insurance.csv to insurance.csv
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %% [markdown]
# Exploracion de datos

# %%
sb.pairplot(dt)

# %%
sb.pairplot(dt, hue="sex")

# %% [markdown]
# Descripción del data set

# %%
dt.describe()
# Out:
#               age         sex         bmi  ...      smoker      region       charges
# count  348.000000  348.000000  348.000000  ...  348.000000  348.000000    348.000000
# mean    39.591954    0.508621   30.676552  ...    0.232759    1.497126  14016.426293
# std     14.417015    0.500646    5.625850  ...    0.423198    1.104089  12638.887852
# min     18.000000    0.000000   15.960000  ...    0.000000    0.000000   1137.011000
# 25%     27.000000    0.000000   26.782500  ...    0.000000    1.000000   4888.466125
# 50%     40.000000    1.000000   30.300000  ...    0.000000    2.000000   9719.305250
# 75%     53.000000    1.000000   34.777500  ...    0.000000    2.000000  19006.316150
# max     64.000000    1.000000   49.060000  ...    1.000000    3.000000  51194.559140
#
# [8 rows x 7 columns]

# %% [markdown]
# Registros Nulos

# %%
dt.isnull()
# Out:
#        age    sex    bmi  children  smoker  region  charges
# 0    False  False  False     False   False   False    False
# 1    False  False  False     False   False   False    False
# 2    False  False  False     False   False   False    False
# 3    False  False  False     False   False   False    False
# 4    False  False  False     False   False   False    False
# ..     ...    ...    ...       ...     ...     ...      ...
# 343  False  False  False     False   False   False    False
# 344  False  False  False     False   False   False    False
# 345  False  False  False     False   False   False    False
# 346  False  False  False     False   False   False    False
# 347  False  False  False     False   False   False    False
#
# [348 rows x 7 columns]

# %%
from sklearn import preprocessing

encoder = preprocessing.LabelEncoder()
dt['sex']= encoder.fit_transform(dt['sex'])
dt['sex'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: sex, dtype: int64

# %%
dt['smoker'] = encoder.fit_transform(dt['smoker'])
dt['smoker'].head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: smoker, dtype: int64
